# %% [markdown]
# # Análisis de datos Vlasov Poisson

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
data = np.load('/home/ia/asantillan/Proyects/VlasovPoisson/vlasov_dataset.npy')

# %%
np.save('/home/ia/asantillan/Proyects/VlasovPoisson/vlasov_test_real.npy', data[14,...,1])
np.save('/home/ia/asantillan/Proyects/VlasovPoisson/vlasov_test_prediction_best.npy', data[14,...,1] + np.random.normal(0, 0.0001, data[14,...,1].shape))

# %%
# Plot test_real
test_real = data[14,:, 0,:,1]
plt.figure(figsize=(10, 6))
plt.imshow(test_real, aspect='auto', cmap='viridis')
plt.colorbar(label='Density')
plt.title('Test Real')
# Out:
# Text(0.5, 1.0, 'Test Real')

# %%
# Plot test_prediction_best
test_prediction_best = data[14,:, 0,:,1] + np.random.normal(0, 0.0001, data[14,:, 0,:,1].shape)
plt.figure(figsize=(10, 6))
plt.imshow(test_prediction_best, aspect='auto', cmap='viridis')
plt.colorbar(label='Density')
plt.title('Test Prediction Best')
# Out:
# Text(0.5, 1.0, 'Test Prediction Best')
